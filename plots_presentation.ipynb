# %%
import pandas as pd
# %matplotlib inline

# %%
evolution = pd.Series(data=[694,314,339,563,305],index=[1,2,3,4,5])
evolution.name = 'nr_deaths'

# %%
ax = evolution.plot(legend=True,xticks=[1,2,3,4,5],figsize=(8,4),ylim=[0,750])
ax.set_xlabel('Submission Number')
# Out:
# Text(0.5,0,'Submission Number')

# %%
df = pd.read_csv('data/train.csv',parse_dates=['Date'])

# %%
df = df.set_index(['Date','City']).sort_index()

# %%
df['Nr_patients'].plot(kind='box',figsize=(8,4))
